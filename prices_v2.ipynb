# %%
# imports
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load the dataset
dataset = pd.read_csv("/Users/Utilizador/Desktop/Bioinf/2º ano/2º semestre/AA/activity-4.2-house_prices.csv", sep=';')
dataset.head(2920)
# Out:
#         Id  LotArea  YearBuilt  BedroomAbvGr  GarageCars  GarageArea  \
# 0        1     8450       2003             3         2.0       548.0
# 1        2     9600       1976             3         2.0       460.0
# 2        3    11250       2001             3         2.0       608.0
# 3        4     9550       1915             3         3.0       642.0
# 4        5    14260       2000             4         3.0       836.0
# ...    ...      ...        ...           ...         ...         ...
# 2914  2915     1936       1970             3         0.0         0.0
# 2915  2916     1894       1970             3         1.0       286.0
# 2916  2917    20000       1960             4         2.0       576.0
# 2917  2918    10441       1992             3         0.0         0.0
# 2918  2919     9627       1993             3         3.0       650.0
#
#       SalePrice
# 0      208500.0
# 1      181500.0
# 2      223500.0
# 3      140000.0
# 4      250000.0
# ...         ...
# ...

# %%
# drop the missing values
dataset = dataset.dropna()

# %%
# See the data without the missing values 
dataset.head(2920)
# Out:
#         Id  LotArea  YearBuilt  BedroomAbvGr  GarageCars  GarageArea  \
# 0        1     8450       2003             3         2.0       548.0
# 1        2     9600       1976             3         2.0       460.0
# 2        3    11250       2001             3         2.0       608.0
# 3        4     9550       1915             3         3.0       642.0
# 4        5    14260       2000             4         3.0       836.0
# ...    ...      ...        ...           ...         ...         ...
# 1455  1456     7917       1999             3         2.0       460.0
# 1456  1457    13175       1978             3         2.0       500.0
# 1457  1458     9042       1941             4         1.0       252.0
# 1458  1459     9717       1950             2         1.0       240.0
# 1459  1460     9937       1965             3         1.0       276.0
#
#       SalePrice
# 0      208500.0
# 1      181500.0
# 2      223500.0
# 3      140000.0
# 4      250000.0
# ...         ...
# ...

# %%
# x will take the independent vaiables 'LotArea':'GarageArea'
df = dataset.loc[:,'LotArea':'GarageArea']
df.head(1460)
# Out:
#       LotArea  YearBuilt  BedroomAbvGr  GarageCars  GarageArea
# 0        8450       2003             3         2.0       548.0
# 1        9600       1976             3         2.0       460.0
# 2       11250       2001             3         2.0       608.0
# 3        9550       1915             3         3.0       642.0
# 4       14260       2000             4         3.0       836.0
# ...       ...        ...           ...         ...         ...
# 1455     7917       1999             3         2.0       460.0
# 1456    13175       1978             3         2.0       500.0
# 1457     9042       1941             4         1.0       252.0
# 1458     9717       1950             2         1.0       240.0
# 1459     9937       1965             3         1.0       276.0
#
# [1460 rows x 5 columns]

# %%
# y -b_0 + b_1x
# x is the independent variable and y is the dependent variable
x = df
y = dataset.SalePrice

# %%
from sklearn import linear_model
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=101)

# %%
ln = linear_model.LinearRegression(normalize=True)
model = ln.fit(x, y)

# %%
predictions = ln.predict(x_test)

# %%
predictions[:20]
# Out:
# array([222781.05511092, 117214.77473924, 191736.10736247, 264605.36056117,
#        282211.96070457,  90514.3041943 , 109010.00301338, 192295.93195543,
#        140026.91602139, 182796.96530951, 201022.95874875, 161859.46615418,
#        182414.33616605, 121520.91453122, 226474.51040538, 225660.29013939,
#        185713.10918474, 148492.46679038, 112405.63499269, 212544.31741841])

# %%
# visualize
plt.scatter(y_test, predictions)

# %%
from sklearn.metrics import mean_squared_error, r2_score
mean_squared_error(y_test, predictions)
# Out:
# 3331443204.3702226

# %%
# the accuracy of this model is 47% 
r2_score(np.array(y_test), predictions)
# Out:
# 0.4705972091032029

# %%
# Bernardo Augusto 2814
